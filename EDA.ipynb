# %% [markdown]
# <a href="https://colab.research.google.com/github/joanalawer/Capstone-Project/blob/main/EDA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Project Tile : Heart Disease Prediction
#
# Goal : Predict the heart disease risk of patients.
#
# Author Name : Joana Lawer & Samuel Osei

# %% [markdown]
# ### Loading Data

# %%
# Import necessary modules
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
from google.colab import drive
drive.mount('/content/gdrive')
df = pd.read_csv('/content/gdrive/My Drive/Colab Notebooks/Data/framingham.csv')
df.head(10)
# Out:
# Mounted at /content/gdrive
#    Unnamed: 0     sex  age  education currentSmoker  cigsPerDay BPMeds  \
# 0           0    male   39        4.0            No         0.0     No
# 1           1  female   46        2.0            No         0.0     No
# 2           2    male   48        1.0           Yes        20.0     No
# 3           3  female   61        3.0           Yes        30.0     No
# 4           4  female   46        3.0           Yes        23.0     No
# 5           5  female   43        2.0            No         0.0     No
# 6           6  female   63        1.0            No         0.0     No
# 7           7  female   45        2.0           Yes        20.0     No
# 8           8    male   52        1.0            No         0.0     No
# 9           9    male   43        1.0           Yes        30.0     No
#
#   prevalentStroke prevalentHyp diabetes  totChol  sysBP  diaBP    BMI  \
# 0              No           No       No    195.0  106.0   70.0  26.97
# 1              No           No       No    250.0  121.0   81.0  28.73
# 2              No           No       No    245.0  127.5   80.0  25.34
# 3              No          Yes       No    225.0  150.0   95.0  28.58
# 4              No           No       No    285.0  130.0   84.0  23.10
# 5              No          Yes       No    228.0  180.0  110.0  30.30
# 6              No           No       No    205.0  138.0   71.0  33.11
# 7              No           No       No    313.0  100.0   71.0  21.68
# 8              No          Yes       No    260.0  141.5   89.0  26.36
# 9              No          Yes       No    225.0  162.0  107.0  23.61
#
#    heartRate  glucose  TenYearCHD
# 0       80.0     77.0           0
# 1       95.0     76.0           0
# 2       75.0     70.0           0
# 3       65.0    103.0           1
# 4       85.0     85.0           0
# 5       77.0     99.0           0
# 6       60.0     85.0           1
# 7       79.0     78.0           0
# 8       76.0     79.0           0
# 9       93.0     88.0           0

# %%
# Load the dataset and view first 10 entries
# df is the variable name of our dataset
# df = pd.read_csv('framingham.csv')
# df.head(10)

# %%
# View shape of dataset (number of rows and columns)
# df.shape
print ('No. of Rows :', df.shape[0], '\nNo. of Columns : ', df.shape[1])
# Out:
# No. of Rows : 4238
# No. of Columns :  17

# %% [markdown]
# - The columns represent the features and the rows represent the entries

# %%
# View the datatype attributes of the features
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4238 entries, 0 to 4237
# Data columns (total 17 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Unnamed: 0       4238 non-null   int64
#  1   sex              4238 non-null   object
#  2   age              4238 non-null   int64
#  3   education        4133 non-null   float64
#  4   currentSmoker    4238 non-null   object
#  5   cigsPerDay       4209 non-null   float64
#  6   BPMeds           4185 non-null   object
#  7   prevalentStroke  4238 non-null   object
#  8   prevalentHyp     4238 non-null   object
#  9   diabetes         4238 non-null   object
#  10  totChol          4188 non-null   float64
#  11  sysBP            4238 non-null   float64
#  12  diaBP            4238 non-null   float64
#  13  BMI              4219 non-null   float64
#  14  heartRate        4237 non-null   float64
#  15  glucose          3850 non-null   float64
#  16  TenYearCHD       4238 non-null   int64
# dtypes: float64(8), int64(3), object(6)
# memory usage: 563.0+ KB

# %%
#  View statistical info of the dataset
df.describe()
# Out:
#         Unnamed: 0          age    education   cigsPerDay      totChol  \
# count  4238.000000  4238.000000  4133.000000  4209.000000  4188.000000
# mean   2118.500000    49.584946     1.978950     9.003089   236.721585
# std    1223.549549     8.572160     1.019791    11.920094    44.590334
# min       0.000000    32.000000     1.000000     0.000000   107.000000
# 25%    1059.250000    42.000000     1.000000     0.000000   206.000000
# 50%    2118.500000    49.000000     2.000000     0.000000   234.000000
# 75%    3177.750000    56.000000     3.000000    20.000000   263.000000
# max    4237.000000    70.000000     4.000000    70.000000   696.000000
#
#              sysBP        diaBP          BMI    heartRate      glucose  \
# count  4238.000000  4238.000000  4219.000000  4237.000000  3850.000000
# mean    132.352407    82.893464    25.802008    75.878924    81.966753
# std      22.038097    11.910850     4.080111    12.026596    23.959998
# min      83.500000    48.000000    15.540000    44.000000    40.000000
# 25%     117.000000    75.000000    23.070000    68.000000    71.000000
# 50%     128.000000    82.000000    25.400000    75.000000    78.000000
# 75%     144.000000    89.875000    28.040000    83.000000    87.000000
# max     295.000000   142.500000    56.800000   143.000000   394.000000
#
#         TenYearCHD
# count  4238.000000
# mean      0.151958
# std       0.359023
# min       0.000000
# 25%       0.000000
# 50%       0.000000
# 75%       0.000000
# max       1.000000

# %%
#  Check for missing values in each feature
df.isnull().sum()
# Out:
# Unnamed: 0           0
# sex                  0
# age                  0
# education          105
# currentSmoker        0
# cigsPerDay          29
# BPMeds              53
# prevalentStroke      0
# prevalentHyp         0
# diabetes             0
# totChol             50
# sysBP                0
# diaBP                0
# BMI                 19
# heartRate            1
# glucose            388
# TenYearCHD           0
# dtype: int64
